-- %%
CREATE TABLE demo_catalog.customer_app.customers
(
    customer_id BIGINT,
    customer_name STRING,
    email STRING,
    country STRING,
    segment STRING,
    annual_revenue DECIMAL(18,2),
    created_date DATE,
    updated_date TIMESTAMP
)
USING DELTA;

INSERT INTO demo_catalog.customer_app.customers
VALUES
(
    1001,
    'ABC Energy Ltd',
    'contact@abcenergy.com',
    'India',
    'Enterprise',
    1200000.00,
    current_date(),
    current_timestamp()
),
(
    1002,
    'Global Oil Corp',
    'info@globaloil.com',
    'USA',
    'Enterprise',
    2500000.00,
    current_date(),
    current_timestamp()
),
(
    1003,
    'Eastern Engineering',
    'admin@eastern.com',
    'India',
    'SMB',
    450000.00,
    current_date(),
    current_timestamp()
),
(
    1004,
    'North Sea Energy',
    'contact@nse.com',
    'UK',
    'Enterprise',
    3200000.00,
    current_date(),
    current_timestamp()
),
(
    1005,
    'Asia Petro',
    'info@asiapetro.com',
    'Singapore',
    'Enterprise',
    1800000.00,
    current_date(),
    current_timestamp()
);

SELECT *
FROM demo_catalog.customer_app.customers;

-- DELETE FROM demo_catalog.customer_app.customers;
